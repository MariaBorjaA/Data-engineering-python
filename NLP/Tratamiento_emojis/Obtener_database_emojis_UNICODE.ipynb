# %% [markdown]
# # Base de datos de emojis

# %% [markdown]
# De la libreria de python de emojis extraer el icono, el nombre y el unicode del emoji,para su posterior clasificación para la interpretación de comentarios positivos, negativos o neutrales.

# %%
import numpy as np
import csv
import emoji

# %%
print(emoji.emojize("Hola :thumbsup:"))
# Out:
# Hola :thumbsup:

# %%
print(emoji.emojize("Python is fun :thumbs_up:",language='en'))
# Out:
# Python is fun 👍

# %%
print(emoji.emojize("Python is fun :cara_sonriendo:",language='es'))
# Out:
# Python is fun 😀

# %%
from emoji.unicode_codes.en import *
from emoji.unicode_codes.es import *

# %%
lista=emoji.unicode_codes.es

# %%
dic_emojis=EMOJI_UNICODE_SPANISH.items()

# %%
Lista_emojis=UNICODE_EMOJI_SPANISH
for i in Lista_emojis:
    print(i)
    print(Lista_emojis[i])
# Out:
# 😀
# :cara_sonriendo:
# 😃
# :cara_sonriendo_con_ojos_grandes:
# 😄
# :cara_sonriendo_con_ojos_sonrientes:
# 😁
# :cara_radiante_con_ojos_sonrientes:
# 😆
# :cara_sonriendo_con_los_ojos_cerrados:
# 😅
# :cara_sonriendo_con_sudor_frío:
# 🤣
# :cara_revolviéndose_de_la_risa:
# 😂
# :cara_llorando_de_risa:
# 🙂
# :cara_sonriendo_ligeramente:
# 🙃
# :cara_al_revés:
# 😉
# :cara_guiñando_el_ojo:
# 😊
# :cara_feliz_con_ojos_sonrientes:
# 😇
# :cara_sonriendo_con_aureola:
# 🥰
# :cara_sonriendo_con_corazones:
# 😍
# :cara_sonriendo_con_ojos_de_corazón:
# 🤩
# :cara_sonriendo_con_estrellas:
# 😘
# :cara_lanzando_un_beso:
# 😗
# :cara_besando:
# ☺️
# :cara_sonriente:
# 😚
# :cara_besando_con_los_ojos_cerrados:
# 😙
# :cara_besando_con_ojos_sonrientes:
# 🥲
# :cara_sonriente_con_lágrima:
# 😋
# :cara_saboreando_comida:
# 😛
# :cara_sacando_la_lengua:
# 😜
# :cara_sacando_la_lengua_y_guiñando_un_ojo:
# 🤪
# :cara_de_loco:
# 😝
# :cara_con_ojos_cerrados_y_lengua_fuera:
# 🤑
# :cara_con_lengua_de_dinero:
# 🤗
# ...

# %%
with open('base_de_datos_emojis_español.csv','w', newline='',encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["emoji","nombre","clase"])
    for i in Lista_emojis:
        data=[i,Lista_emojis[i],0]
        writer.writerow(data)
# Out:
# 🏴󠁧󠁢󠁷󠁬󠁳󠁿
# :bandera_gales:
